# %%
from tasks import flip_flop
from backend import networks
import tensorflow as tf
import numpy as np

# %%
n_steps = [20, 50, 100, 200, 400]
n_rec = [10, 50, 200, 500]
N_batch = [32]

for ns in n_steps:
    for nr in n_rec:
        for nb in N_batch:
            q = (ns - 5) / 10
            s = (ns - 5) / 5 - q

            params = flip_flop.set_params(N_rec=nr, N_turns=5, input_wait=5, quiet_gap=q, stim_dur=s,
                                          var_delay_length=0, stim_noise=0.1, rec_noise=0.1,
                                          N_batch=nb, dale_ratio=0.8, dt=10, tau=100)

            generator = flip_flop.generate_train_trials(params)
            model = networks.Model(params)

            configuration = tf.ConfigProto(inter_op_parallelism_threads=10, intra_op_parallelism_threads=10)
            sess = tf.Session(config=configuration)

            t = model.train(sess, generator, training_iters=10000, learning_rate=.01, weights_path=None)

            print "n_steps: %d, n_rec: %d, n_batch: %d, time: %f" %(ns, nr, nb, t)

            tf.reset_default_graph()
# Out:
# //anaconda/lib/python2.7/site-packages/backend/networks.py:53: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.recurrent_connectivity_mask == None:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-26f39e3dc954> in <module>()
#      19             sess = tf.Session(config=configuration)
#      20
# ---> 21             t = model.train(sess, generator, training_iters=10000, learning_rate=.01, weights_path=None)
#      22
#      23             print "n_steps: %d, n_rec: %d, n_batch: %d, time: %f" %(ns, nr, nb, t)
#
# //anaconda/lib/python2.7/site-packages/backend/networks.pyc in train(self, sess, generator, learning_rate, training_iters, batch_size, display_step, weights_path)
#     415         # train with gradient clipping
#     416         optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
# --> 417         grads = optimizer.compute_gradients(self.loss)
#     418         clipped_grads = [(tf.clip_by_norm(grad, 1.0), var)
#     419                          if grad is not None else (grad, var)
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/training/optimizer.pyc in compute_gradients(self, loss, var_list, gate_gradients, aggregation_method, colocate_gradients_with_ops, grad_loss)
#     352         gate_gradients=(gate_gradients == Optimizer.GATE_OP),
#     353         aggregation_method=aggregation_method,
# --> 354         colocate_gradients_with_ops=colocate_gradients_with_ops)
#     355     if gate_gradients == Optimizer.GATE_GRAPH:
#     356       grads = control_flow_ops.tuple(grads)
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/ops/gradients_impl.pyc in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method)
#     480                 # If grad_fn was found, do not use SymbolicGradient even for
#     481                 # functions.
# --> 482                 in_grads = grad_fn(op, *out_grads)
#     483               else:
#     484                 # For function call ops, we add a 'SymbolicGradient'
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/ops/math_grad.pyc in _MulGrad(op, grad)
#     611   x = math_ops.conj(x)
#     612   y = math_ops.conj(y)
# --> 613   return (array_ops.reshape(math_ops.reduce_sum(grad * y, rx), sx),
#     614           array_ops.reshape(math_ops.reduce_sum(x * grad, ry), sy))
#     615
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/ops/gen_array_ops.pyc in reshape(tensor, shape, name)
#    2628   """
#    2629   result = _op_def_lib.apply_op("Reshape", tensor=tensor, shape=shape,
# -> 2630                                 name=name)
#    2631   return result
#    2632
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.pyc in apply_op(self, op_type_name, name, **keywords)
#     761         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     762                          input_types=input_types, attrs=attr_protos,
# --> 763                          op_def=op_def)
#     764         if output_structure:
#     765           outputs = op.outputs
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2395                     original_op=self._default_original_op, op_def=op_def)
#    2396     if compute_shapes:
# -> 2397       set_shapes_for_outputs(ret)
#    2398     self._add_op(ret)
#    2399     self._record_op_seen_by_control_dependencies(ret)
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in set_shapes_for_outputs(op)
#    1755       shape_func = _call_cpp_shape_fn_and_require_op
#    1756
# -> 1757   shapes = shape_func(op)
#    1758   if shapes is None:
#    1759     raise RuntimeError(
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in call_with_requiring(op)
#    1705
#    1706   def call_with_requiring(op):
# -> 1707     return call_cpp_shape_fn(op, require_shape_fn=True)
#    1708
#    1709   _call_cpp_shape_fn_and_require_op = call_with_requiring
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/framework/common_shapes.pyc in call_cpp_shape_fn(op, input_tensors_needed, input_tensors_as_shapes_needed, debug_python_shape_fn, require_shape_fn)
#     608     res = _call_cpp_shape_fn_impl(op, input_tensors_needed,
#     609                                   input_tensors_as_shapes_needed,
# --> 610                                   debug_python_shape_fn, require_shape_fn)
#     611     if not isinstance(res, dict):
#     612       # Handles the case where _call_cpp_shape_fn_impl calls unknown_shape(op).
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/framework/common_shapes.pyc in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, debug_python_shape_fn, require_shape_fn)
#     658   arr = [serialized_unknown_shape for i in input_shapes]
#     659   for idx in input_tensors_as_shapes_needed:
# --> 660     s = tensor_util.constant_value_as_shape(op.inputs[idx])
#     661     if s is not None:
#     662       arr[idx] = s.as_proto().SerializeToString()
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/framework/tensor_util.pyc in constant_value_as_shape(tensor)
#     742   else:
#     743     ret = tensor_shape.unknown_shape(shape[0].value)
# --> 744     value = constant_value(tensor)
#     745     if value is not None:
#     746       ret = ret.merge_with(tensor_shape.TensorShape(
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/framework/tensor_util.pyc in constant_value(tensor)
#     679     TypeError: if tensor is not an ops.Tensor.
#     680   """
# --> 681   ret = _ConstantValue(tensor)
#     682   if ret is not None:
#     683     # The caller may now depend on the constant value of `tensor`, so we
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/framework/tensor_util.pyc in _ConstantValue(tensor)
#     577     raise TypeError("tensor is not a Tensor")
#     578   if tensor.op.type == "Const":
# --> 579     return MakeNdarray(tensor.op.get_attr("value"))
#     580   elif tensor.op.type == "Shape":
#     581     input_shape = tensor.op.inputs[0].get_shape()
#
# //anaconda/lib/python2.7/site-packages/tensorflow/python/framework/tensor_util.pyc in MakeNdarray(tensor)
#     470   """
#     471   shape = [d.size for d in tensor.tensor_shape.dim]
# --> 472   num_elements = np.prod(shape)
#     473   tensor_dtype = dtypes.as_dtype(tensor.dtype)
#     474   dtype = tensor_dtype.as_numpy_dtype
#
# //anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in prod(a, axis, dtype, out, keepdims)
#    2496
#    2497     return _methods._prod(a, axis=axis, dtype=dtype,
# -> 2498                           out=out, **kwargs)
#    2499
#    2500
#
# //anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _prod(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 35     return umr_prod(a, axis, dtype, out, keepdims)
#      36
#      37 def _any(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:
